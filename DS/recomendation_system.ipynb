# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')
import re
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
items=pd.read_csv("all_in_one.csv")

# %%
items
# Out:
#     Unnamed: 0                  address_name  \
# 0            0                    Усова, 19а
# 1            1           проспект Ленина, 62
# 2            2          Московский тракт, 40
# 3            3                      Обруб, 6
# 4            4                   Смирнова, 5
# 5            5                   Нахимова, 2
# 6            6           Розы Люксембург, 79
# 7            7            площадь Ленина, 10
# 8            8              улица Кулёва, 24
# 9            9           Розы Люксембург, 16
# 10          10           проспект Ленина, 1в
# 11          11                   Учебная, 46
# 12          12     Кооперативный переулок, 2
# 13          13          переулок Нахимова, 2
# 14          14                     Усова, 9Б
# 15          15  улица Красноармейская, 151/1
# 16          16      улица Дзержинского, 34/3
# 17          17          проспект Ленина, 121
# 18          18             улица Гагарина, 2
# 19          19             улица Гагарина, 2
# 20          20            проспект Мира, 19а
# 21          21           проспект Фрунзе, 77
# 22          22         переулок Макушина, 12
# 23          23      Ново-Соборная площадь, 2
# 24          24           проспект Фрунзе, 90
# 25          25       Асфальтовый переулок, 8
# 26          26              улица Кулёва, 26
# 27          27                  Яковлева, 59
# 28          28       Карповский переулок, 12
# 29          29    улица Красноармейская, 135
# 30          30    Комсомольский проспект, 70
# 31          31             Карла Маркса, 11а
# 32          32      Иркутский тракт, 61 ст12
# 33          33          проспект Ленина, 82а
# 34          34           Розы Люксембург, 16
# 35          35    улица Алексея Беленца, 9/1
# 36          36          Трифонова, 22 блок А
# 37          37           Иркутский тракт, 68
# 38          38            Пролетарская, 38/7
# 39          39         улица Елизаровых, 27а
# 40          40                    Усова, 11Б
# 41          41   улица Красноармейская, 122г
# 42          42           проспект Ленина, 97
# 43          43          улица Котовского, 19
# 44          44           проспект Ленина, 41
# 45          45   улица Красноармейская, 101а
# 46          46                   Нахимова, 2
# 47          47               Сергея Лазо, 1Б
# 48          48          проспект Ленина, 85а
# 49          49           улица Говорова, 19в
#
#                                                   ads  \
# 0   {'article': 'Хрустящий лаваш, сочное мясо и ую...
# 1                                                 NaN
# 2   {'article': '«Шашлычный дом» — круглосуточная ...
# 3   {'article': 'TomYumBar — уникальный формат зав...
# 4   {'article': 'Ждём тебя в гости!', 'text': 'Вку...
# 5   {'article': 'Кажется, этому городу нужен новый...
# 6   {'article': 'Идеальное место, чтобы начать сво...
# 7   {'article': 'Грузинские пряности и европейские...
# 8   {'article': '«КУХНЯ» — это место для уютных за...
# 9   {'article': 'Kitchen, bar and music*.<br />The...
# 10  {'article': 'Любимые блюда всегда с вами! <br ...
# 11  {'article': '<br />•&nbsp;Бар.<br />•&nbsp;Вку...
# 12  {'article': '«Река 827» — пожалуй, самый вкусн...
# 13  {'article': 'Мы собираем сэндвичи прямо перед ...
# 14  {'article': 'Детям до 13 лет в подарок какао! ...
# 15  {'article': 'Наше кафе уютной кухни с улыбкой ...
# 16  {'article': 'Ресторан для всей семьи в любое в...
# 17  {'article': 'Необычный интерьер, навеянный тво...
# 18  {'article': '«Инжир» — одно из самых первых те...
# 19  {'article': 'Ресторан «Бамбук» — паназиатская ...
# 20  {'article': 'Кафе грузинской кухни<br />Мы час...
# 21  {'article': 'Хочется чего-нибудь сытного, вкус...
# 22  {'article': 'Новый, стильный, современный отел...
# 23  {'article': 'Гастрономическое бистро Nova — эт...
# 24  {'article': 'Мы любим кормить людей. Еда для н...
# 25  {'article': 'Топовый бургер + картошка + напит...
# 26  {'article': 'Стереокафе Santa Monica — мультиф...
# 27  {'article': 'Собственно говоря, а почему бы и ...
# 28  {'article': 'Мы рады приветствовать вас в кафе...
# 29  {'article': 'Аромат свежей выпечки, хруст возд...
# 30  {'article': 'Доставим праздничные блюда домой ...
# 31  {'article': 'Бар «ПабиК» снова открыт!<br /><b...
# 32  {'article': 'Незабываемый романтический вечер ...
# 33  {'article': 'Для вас на свет мы появились!<br ...
# 34  {'article': 'Стейк-хаус «Антрекот» — это завед...
# 35  {'article': "«К ПАПЕ НА'PIZZA», гастробар<br /...
# 36  {'article': 'Гриль-бар «ГАЛЕРЕЯ» — это классич...
# 37  {'article': 'Рестобар «ЗдесьВамНеТам» — популя...
# 38  {'article': 'Доставка еды в офис и на дом.<br ...
# 39  {'article': 'Магазины-бары Garage — это высоки...
# 40  {'article': 'Легендарная курочка из Южной Коре...
# 41  {'article': '«Мыльная опера», Томск.<br />Кара...
# 42  {'article': 'Добро пожаловать в Pho Tigers! Ка...
# 43  {'article': 'Приглашаем посетить наше кафе и о...
# 44  {'article': 'Латиноамериканский гастробар в це...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                      attribute_groups                 id  \
# 0   [{'attributes': [{'id': '70000201006747423', '...  70000001056052192
# 1   [{'attributes': [{'id': '70000201006747423', '...  70000001039197290
# 2   [{'attributes': [{'id': '70000201006747423', '...  70000001007548790
# 3   [{'attributes': [{'id': '70000201006747423', '...  70000001033092714
# 4   [{'attributes': [{'id': '70000201006747423', '...  70000001069065093
# 5   [{'attributes': [{'id': '70000201006747423', '...  70000001065471097
# 6   [{'attributes': [{'id': '70000201006747423', '...    422741746350056
# 7   [{'attributes': [{'id': '70000201006747423', '...  70000001034727703
# 8   [{'attributes': [{'id': '70000201006752761', '...  70000001024362908
# 9   [{'attributes': [{'id': '70000201006747423', '...  70000001019311632
# 10  [{'attributes': [{'id': '70000201006747423', '...  70000001032182633
# 11  [{'attributes': [{'id': '70000201006747423', '...  70000001044756053
# 12  [{'attributes': [{'id': '70000201006747423', '...  70000001006736825
# 13  [{'attributes': [{'id': '70000201006747423', '...  70000001043339969
# 14  [{'attributes': [{'id': '70000201006747423', '...  70000001026873949
# 15  [{'attributes': [{'id': '70000201006747423', '...    422740746299978
# 16  [{'attributes': [{'id': '70000201006750805', '...  70000001075243532
# 17  [{'attributes': [{'id': '70000201006747423', '...    422740746242398
# 18  [{'attributes': [{'id': '70000201006747423', '...    422740746052944
# 19  [{'attributes': [{'id': '70000201006747423', '...    422740746095314
# 20  [{'attributes': [{'id': '70000201006747423', '...  70000001029069533
# 21  [{'attributes': [{'id': '70000201006747423', '...  70000001065542142
# 22  [{'attributes': [{'id': '70000201006748004', '...  70000001066379205
# 23  [{'attributes': [{'id': '70000201006747423', '...  70000001066101507
# 24  [{'attributes': [{'id': '70000201006747423', '...  70000001029574004
# 25  [{'attributes': [{'id': '70000201006747423', '...  70000001029908413
# 26  [{'attributes': [{'id': '70000201006747423', '...  70000001038511964
# 27  [{'attributes': [{'id': '70000201006756031', '...  70000001041145942
# 28  [{'attributes': [{'id': '70000201006747423', '...  70000001007410397
# 29  [{'attributes': [{'id': '70000201006748004', '...  70000001045193961
# 30  [{'attributes': [{'id': '70000201006747423', '...  70000001032775451
# 31  [{'attributes': [{'id': '70000201006747423', '...    422740746183350
# 32  [{'attributes': [{'id': '70000201006747423', '...    422740746080455
# 33  [{'attributes': [{'id': '70000201006747423', '...  70000001045371342
# 34  [{'attributes': [{'id': '70000201006747423', '...  70000001024853369
# 35  [{'attributes': [{'id': '70000201006747423', '...  70000001048132291
# 36  [{'attributes': [{'id': '70000201006752761', '...  70000001006338388
# 37  [{'attributes': [{'id': '70000201006747423', '...  70000001028323706
# 38  [{'attributes': [{'id': '70000201006754263', '...  70000001053657643
# 39  [{'attributes': [{'id': '70000201006751153', '...  70000001067269176
# 40  [{'attributes': [{'id': '70000201006747423', '...  70000001059971139
# 41  [{'attributes': [{'id': '70000201006747423', '...  70000001036187192
# 42  [{'attributes': [{'id': '70000201006747423', '...  70000001034903505
# 43  [{'attributes': [{'id': '70000201006747423', '...  70000001035530724
# 44  [{'attributes': [{'id': '70000201006748029', '...  70000001052467336
# 45  [{'attributes': [{'id': '70000201006747423', '...    422741746676019
# 46  [{'attributes': [{'id': '70000201006747423', '...    422740746481943
# 47  [{'attributes': [{'id': '70000201006747423', '...  70000001044960809
# 48  [{'attributes': [{'id': '70000201006747423', '...  70000001027792986
# 49  [{'attributes': [{'id': '70000201006747423', '...    422740746329503
#
#                                              name  \
# 0                Шаурмания, кафе быстрого питания
# 1                          Барин, коктейльный бар
# 2                             Шашлычный дом, кафе
# 3              TomYumBar, кафе паназиатской кухни
# 4                                     Ватан, кафе
# 5             ПхиПхи, ресторан паназиатской кухни
# 6                                           Dolce
# 7                    Пряности и радости, ресторан
# 8                                КУХНЯ, повар-бар
# 9                       The burger lab, гастробар
# 10       Мама, я дома!, ресторан грузинской кухни
# 11                                  Highlight Bar
# 12             Река 827, ресторан авторской кухни
# 13                                         Subway
# 14              Территория Кофе, экспресс-кофейня
# 15             Колобок.Ру, сеть кафе уютной кухни
# 16                                          Елань
# 17              PastaMama, кафе итальянской кухни
# 18                                Инжир, ресторан
# 19            Бамбук, ресторан паназиатской кухни
# 20                             ХинКали-GaлИ, кафе
# 21                      Додо Пицца, сеть пиццерий
# 22                                Glogg, ресторан
# 23                                           Nova
# 24                                    Гости, кафе
# 25  Бургер Кинг, сеть ресторанов быстрого питания
# 26                             Santa Monica, кафе
# 27               Ё, служба доставки суши и роллов
# 28                                   Байкал, кафе
# 29       А мы тут плюшками балуемся, кафе-пекарня
# 30                                     Союз, кафе
# 31                                     ПабиК, бар
# 32                              Шустофф, ресторан
# 33                         Пицца cиница, пиццерия
# 34                           Антрекот, стейк-хаус
# 35                     К ПАПЕ НА`PIZZA, гастробар
# 36                             Галерея, гриль-бар
# 37                        ЗдесьВамНеТам, ресторан
# 38                            Доставка Саша варит
# 39                                         Garage
# 40           Kannam Сhicken, кафе корейской кухни
# 41                    Мыльная опера, караоке-клуб
# 42               Pho Tigers, кафе азиатской кухни
# 43                                  Бульвар, кафе
# 44     El Mucho Bar, латиноамериканский гастробар
# 45                           Шашлыкоff, гриль-бар
# 46                               Буланже, кофейня
# 47                                 Безумно.Шаурма
# 48                       Мэйк лав пицца, пиццерия
# 49                       Пицце-Рио, кафе-пиццерия
#
#                                             reviews_x    type  \
# 0   {'general_rating': 4.3, 'general_review_count'...  branch
# 1   {'general_rating': 4.6, 'general_review_count'...  branch
# 2   {'general_rating': 4.4, 'general_review_count'...  branch
# 3   {'general_rating': 3.6, 'general_review_count'...  branch
# 4   {'general_rating': 4.8, 'general_review_count'...  branch
# 5   {'general_rating': 3.9, 'general_review_count'...  branch
# 6   {'general_rating': 4.5, 'general_review_count'...  branch
# 7   {'general_rating': 4, 'general_review_count': ...  branch
# 8   {'general_rating': 4.2, 'general_review_count'...  branch
# 9   {'general_rating': 4.2, 'general_review_count'...  branch
# 10  {'general_rating': 4.1, 'general_review_count'...  branch
# 11  {'general_rating': 4.6, 'general_review_count'...  branch
# 12  {'general_rating': 4.4, 'general_review_count'...  branch
# 13  {'general_rating': 3.1, 'general_review_count'...  branch
# 14  {'general_rating': 4.4, 'general_review_count'...  branch
# 15  {'general_rating': 3.9, 'general_review_count'...  branch
# 16  {'general_rating': 5, 'general_review_count': ...  branch
# 17  {'general_rating': 3.6, 'general_review_count'...  branch
# 18  {'general_rating': 4.2, 'general_review_count'...  branch
# 19  {'general_rating': 4.1, 'general_review_count'...  branch
# 20  {'general_rating': 3.5, 'general_review_count'...  branch
# 21  {'general_rating': 4.1, 'general_review_count'...  branch
# 22  {'general_rating': 4.8, 'general_review_count'...  branch
# 23  {'general_rating': 3.5, 'general_review_count'...  branch
# 24  {'general_rating': 3.9, 'general_review_count'...  branch
# 25  {'general_rating': 2.5, 'general_review_count'...  branch
# 26  {'general_rating': 4.3, 'general_review_count'...  branch
# 27  {'general_rating': 4.1, 'general_review_count'...  branch
# 28  {'general_rating': 4.2, 'general_review_count'...  branch
# 29  {'general_rating': 4, 'general_review_count': ...  branch
# 30  {'general_rating': 4.3, 'general_review_count'...  branch
# 31  {'general_rating': 4.1, 'general_review_count'...  branch
# 32  {'general_rating': 4.2, 'general_review_count'...  branch
# 33  {'general_rating': 3.7, 'general_review_count'...  branch
# 34  {'general_rating': 4.4, 'general_review_count'...  branch
# 35  {'general_rating': 4.6, 'general_review_count'...  branch
# 36  {'general_rating': 4.3, 'general_review_count'...  branch
# 37  {'general_rating': 4.3, 'general_review_count'...  branch
# 38  {'general_rating': 4.1, 'general_review_count'...  branch
# 39  {'general_rating': 3.3, 'general_review_count'...  branch
# 40  {'general_rating': 4.6, 'general_review_count'...  branch
# 41  {'general_rating': 3.5, 'general_review_count'...  branch
# 42  {'general_rating': 4.1, 'general_review_count'...  branch
# 43  {'general_rating': 4.5, 'general_review_count'...  branch
# 44  {'general_rating': 4.2, 'general_review_count'...  branch
# 45  {'general_rating': 4.1, 'general_review_count'...  branch
# 46  {'general_rating': 4, 'general_review_count': ...  branch
# 47  {'general_rating': 4.7, 'general_review_count'...  branch
# 48  {'general_rating': 4.6, 'general_review_count'...  branch
# 49  {'general_rating': 3.4, 'general_review_count'...  branch
#
#          address_comment                        full_name purpose_name  \
# 0                    NaN                              NaN          NaN
# 1                    NaN                              NaN          NaN
# 2                    NaN                              NaN          NaN
# 3                    NaN                              NaN          NaN
# 4                 2 этаж                              NaN          NaN
# 5         цокольный этаж                              NaN          NaN
# 6                    NaN                              NaN          NaN
# 7                    NaN        Томск, площадь Ленина, 10     Ресторан
# 8                    NaN                              NaN          NaN
# 9                 1 этаж                              NaN          NaN
# 10                3 этаж                              NaN          NaN
# 11                3 этаж                              NaN          NaN
# 12                1 этаж                              NaN          NaN
# 13                   NaN                              NaN          NaN
# 14                   NaN                 Томск, Усова, 9Б      Магазин
# 15                   NaN                              NaN          NaN
# 16                   NaN                              NaN          NaN
# 17  1 этаж; правое крыло                              NaN          NaN
# 18                2 этаж                              NaN          NaN
# 19                   NaN                              NaN          NaN
# 20                   NaN                              NaN          NaN
# 21                   NaN                              NaN          NaN
# 22                   NaN                              NaN          NaN
# 23                   NaN                              NaN          NaN
# 24                   NaN                              NaN          NaN
# 25                1 этаж                              NaN          NaN
# 26                   NaN                              NaN          NaN
# 27                   NaN                              NaN          NaN
# 28        цокольный этаж                              NaN          NaN
# 29                   NaN                              NaN          NaN
# 30                2 этаж                              NaN          NaN
# 31                   NaN                              NaN          NaN
# 32                   NaN  Томск, Иркутский тракт, 61 ст12    Кафе, бар
# 33                   NaN                              NaN          NaN
# 34                2 этаж                              NaN          NaN
# 35        цокольный этаж                              NaN          NaN
# 36        цокольный этаж                              NaN          NaN
# 37        цокольный этаж                              NaN          NaN
# 38                   NaN                              NaN          NaN
# 39                   NaN                              NaN          NaN
# 40                2 этаж                              NaN          NaN
# 41                   NaN                              NaN          NaN
# 42                   NaN                              NaN          NaN
# 43                   NaN                              NaN          NaN
# 44                2 этаж                              NaN          NaN
# 45                1 этаж                              NaN          NaN
# 46                2 этаж                              NaN          NaN
# 47                   NaN                              NaN          NaN
# 48                1 этаж                              NaN          NaN
# 49                1 этаж                              NaN          NaN
#
#     avg_price  general_rating  \
# 0         270             4.3
# 1        1200             4.6
# 2         230             4.4
# 3        1000             3.6
# 4         500             4.8
# 5        1000             3.9
# 6         350             4.5
# 7        2500             4.0
# 8         360             4.2
# 9         600             4.2
# 10       1700             4.1
# 11       1200             4.6
# 12       1700             4.4
# 13        300             3.1
# 14        200             4.4
# 15        180             3.9
# 16          0             5.0
# 17       1200             3.6
# 18       1500             4.2
# 19       1500             4.1
# 20        550             3.5
# 21        514             4.1
# 22          0             4.8
# 23        825             3.5
# 24        800             3.9
# 25        450             2.5
# 26       1000             4.3
# 27          0             4.1
# 28        300             4.2
# 29          0             4.0
# 30       1100             4.3
# 31       1200             4.1
# 32       1800             4.2
# 33        495             3.7
# 34       1000             4.4
# 35       1000             4.6
# 36        400             4.3
# 37        790             4.3
# 38          0             4.1
# 39          0             3.3
# 40        600             4.6
# 41       1500             3.5
# 42        600             4.1
# 43       1500             4.5
# 44          0             4.2
# 45        500             4.1
# 46        500             4.0
# 47        250             4.7
# 48        350             4.6
# 49        375             3.4
#
#                                              cuisines  \
# 0                                                 NaN
# 1                                                 NaN
# 2                   Кавказская кухня, Армянская кухня
# 3                                  Паназиатская кухня
# 4                    Восточная кухня, Еврейская кухня
# 5                                  Паназиатская кухня
# 6                                                 NaN
# 7                 Грузинская кухня, Европейская кухня
# 8   Азиатская кухня, Русская кухня, Европейская кухня
# 9   Европейская кухня, Вегетарианская кухня, Амери...
# 10                                   Грузинская кухня
# 11                   Русская кухня, Европейская кухня
# 12                                  Европейская кухня
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17               Итальянская кухня, Европейская кухня
# 18                                    Восточная кухня
# 19                 Японская кухня, Паназиатская кухня
# 20                                   Грузинская кухня
# 21                                                NaN
# 22                                                NaN
# 23               Итальянская кухня, Европейская кухня
# 24                   Русская кухня, Европейская кухня
# 25                                                NaN
# 26  Мексиканская кухня, Европейская кухня, Америка...
# 27                                                NaN
# 28    Бурятская кухня, Японская кухня, Якутская кухня
# 29                                                NaN
# 30                   Русская кухня, Европейская кухня
# 31                                  Европейская кухня
# 32                   Русская кухня, Европейская кухня
# 33                                  Итальянская кухня
# 34              Европейская кухня, Американская кухня
# 35                                                NaN
# 36                                                NaN
# 37  Итальянская кухня, Японская кухня, Европейская...
# 38                                                NaN
# 39                                                NaN
# 40                     Корейская кухня, Тайская кухня
# 41  Итальянская кухня, Русская кухня, Европейская ...
# 42                  Паназиатская кухня, Тайская кухня
# 43                   Русская кухня, Европейская кухня
# 44                Гавайская кухня, Мексиканская кухня
# 45                                      Русская кухня
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                             reviews_y
# 0   ['Очень вкусная шаурма, прям реально! Впечатли...
# 1   ['Замечательно и весело!спасибо 🥰', 'Атмосферн...
# 2   ['Сочные стейки, приготовленные в тандыре - бе...
# 3   ['Обслуживание ниже среднего. Официантов не до...
# 4   ['Хочу рассказать о этом заведение. Был первый...
# 5   ['Дизайн этого ресторана меня покорил сразу, я...
# 6   ['В качестве гостя в Томске я уже пятый раз, н...
# 7   ['На летней веранде обслуживание НОЛЬ!!! После...
# 8   ['Были на бизнес ланче.\nЕда вкусная!\nОбслужи...
# 9   ['Место с отличными бургерами, вежливыми и чут...
# 10  ['Я не первый раз у вас и каждый раз все больш...
# 11  ['Отличное место! Была у вас в первые и обязат...
# 12  ['Ресторан супер, вежливый и отзывчивый персон...
# 13  ['Тут знают, что котлеты надо разогревать отде...
# 14  ['Очень вкусные завтраки и кофе!\nОфицианты са...
# 15  ['Что хочется сказать об этом заведении.  Начн...
# 16  ['Если у вас есть желание попробовать новые вк...
# 17  ['Очень грустно! Так хотелось ризотто но в ито...
# 18  ['Отмечали юбилей серебряной свадьбы с мужем. ...
# 19  ['Роллы как всегда вкусные, лучшие в городе. Н...
# 20  ['Добрый день. Сильно понравилось кафе "ХинКал...
# 21  ['Все отлично 🙌🏻', 'Красивые милые девочки, ка...
# 22  ['Очень приятное место! Чисто, доброжелательно...
# 23  ['Добрый день,\n\nЯ хотел бы выразить свою бла...
# 24  ['Хорошее место', 'Кухня приличная, даже вкусн...
# 25  ['Все понравилось, вкусно', 'Долго отдавали за...
# 26  ['Вкусно, все что взяли 10 из 10.', 'Чудесное ...
# 27  ['Быстрая доставка всё супер', 'Фаворит среди ...
# 28  ['Прекрасное место!\nКормят ну очень вкусно!\n...
# 29  ['Завтраки интересные и вкусные, народу куча, ...
# 30  ['Было 40 минут времени, решила поужинать. \nВ...
# 31  ['Замечательное место. Понравилось меню, обслу...
# 32  ['27.05.2023 отмечали свадьбу. С выбором ресто...
# 33  ['Обещали приготовить пиццу через 15 мин, в ре...
# 34  ['✨Была бы оценка 10, я бы поставила 10/10. ✨З...
# 35  ['Доброго дня, была в вашем заведения, мне оче...
# 36  ['Очень хорошее заведение: вкусная еда, отличн...
# 37  ['Посоветовал знакомый сходить в этот бар. Поп...
# 38  ['Всегда раньше покупала вашу продукцию в буфе...
# 39  ['Получили вот такой флаер, идем по пути, дума...
# 40  ['Очень вкусные крылья - не все соусы понравил...
# 41  ['Был первый раз очень понравилось. Персонал с...
# 42  ['Мало места в кафе.Небыло в меню некоторых бл...
# 43  ['быстрое и качественное обслуживание.', 'Ходи...
# 44  ['Очень приятное место с хорошей кухней. Быстр...
# 45  ['Зачем вводить систему с песочными часами есл...
# 46  ['Ну Во-первых ОЧ вкусно! Кофе- бесподобный! П...
# 47  ['Топ шава, берите пикантная+шрирача+холопенье...
# 48  ['Пишу, не откладывая в долгий ящик.\nПолчаса ...
# 49  ['Очень миленько у них. А вообще часто берем и...

# %% [markdown]
# Удаление ненужных столбцов
#
# Удаление дубликатов
#
# Удалить значения NaN из набора данных
#
# Изменение имен столбцов
#
# Преобразования данных
#
# Очистка данных
#
# Изменение имен столбцов

# %%
items.duplicated().sum()
items.drop_duplicates(inplace=True)

items.isnull().sum()
# items.dropna(how='any',inplace=True)
# Out:
# Unnamed: 0           0
# address_name         0
# ads                  6
# attribute_groups     0
# id                   0
# name                 0
# reviews_x            0
# type                 0
# address_comment     29
# full_name           47
# purpose_name        47
# avg_price            0
# general_rating       0
# cuisines            20
# reviews_y            0
# dtype: int64

# %%
items
# Out:
#     Unnamed: 0                  address_name  \
# 0            0                    Усова, 19а
# 1            1           проспект Ленина, 62
# 2            2          Московский тракт, 40
# 3            3                      Обруб, 6
# 4            4                   Смирнова, 5
# 5            5                   Нахимова, 2
# 6            6           Розы Люксембург, 79
# 7            7            площадь Ленина, 10
# 8            8              улица Кулёва, 24
# 9            9           Розы Люксембург, 16
# 10          10           проспект Ленина, 1в
# 11          11                   Учебная, 46
# 12          12     Кооперативный переулок, 2
# 13          13          переулок Нахимова, 2
# 14          14                     Усова, 9Б
# 15          15  улица Красноармейская, 151/1
# 16          16      улица Дзержинского, 34/3
# 17          17          проспект Ленина, 121
# 18          18             улица Гагарина, 2
# 19          19             улица Гагарина, 2
# 20          20            проспект Мира, 19а
# 21          21           проспект Фрунзе, 77
# 22          22         переулок Макушина, 12
# 23          23      Ново-Соборная площадь, 2
# 24          24           проспект Фрунзе, 90
# 25          25       Асфальтовый переулок, 8
# 26          26              улица Кулёва, 26
# 27          27                  Яковлева, 59
# 28          28       Карповский переулок, 12
# 29          29    улица Красноармейская, 135
# 30          30    Комсомольский проспект, 70
# 31          31             Карла Маркса, 11а
# 32          32      Иркутский тракт, 61 ст12
# 33          33          проспект Ленина, 82а
# 34          34           Розы Люксембург, 16
# 35          35    улица Алексея Беленца, 9/1
# 36          36          Трифонова, 22 блок А
# 37          37           Иркутский тракт, 68
# 38          38            Пролетарская, 38/7
# 39          39         улица Елизаровых, 27а
# 40          40                    Усова, 11Б
# 41          41   улица Красноармейская, 122г
# 42          42           проспект Ленина, 97
# 43          43          улица Котовского, 19
# 44          44           проспект Ленина, 41
# 45          45   улица Красноармейская, 101а
# 46          46                   Нахимова, 2
# 47          47               Сергея Лазо, 1Б
# 48          48          проспект Ленина, 85а
# 49          49           улица Говорова, 19в
#
#                                                   ads  \
# 0   {'article': 'Хрустящий лаваш, сочное мясо и ую...
# 1                                                 NaN
# 2   {'article': '«Шашлычный дом» — круглосуточная ...
# 3   {'article': 'TomYumBar — уникальный формат зав...
# 4   {'article': 'Ждём тебя в гости!', 'text': 'Вку...
# 5   {'article': 'Кажется, этому городу нужен новый...
# 6   {'article': 'Идеальное место, чтобы начать сво...
# 7   {'article': 'Грузинские пряности и европейские...
# 8   {'article': '«КУХНЯ» — это место для уютных за...
# 9   {'article': 'Kitchen, bar and music*.<br />The...
# 10  {'article': 'Любимые блюда всегда с вами! <br ...
# 11  {'article': '<br />•&nbsp;Бар.<br />•&nbsp;Вку...
# 12  {'article': '«Река 827» — пожалуй, самый вкусн...
# 13  {'article': 'Мы собираем сэндвичи прямо перед ...
# 14  {'article': 'Детям до 13 лет в подарок какао! ...
# 15  {'article': 'Наше кафе уютной кухни с улыбкой ...
# 16  {'article': 'Ресторан для всей семьи в любое в...
# 17  {'article': 'Необычный интерьер, навеянный тво...
# 18  {'article': '«Инжир» — одно из самых первых те...
# 19  {'article': 'Ресторан «Бамбук» — паназиатская ...
# 20  {'article': 'Кафе грузинской кухни<br />Мы час...
# 21  {'article': 'Хочется чего-нибудь сытного, вкус...
# 22  {'article': 'Новый, стильный, современный отел...
# 23  {'article': 'Гастрономическое бистро Nova — эт...
# 24  {'article': 'Мы любим кормить людей. Еда для н...
# 25  {'article': 'Топовый бургер + картошка + напит...
# 26  {'article': 'Стереокафе Santa Monica — мультиф...
# 27  {'article': 'Собственно говоря, а почему бы и ...
# 28  {'article': 'Мы рады приветствовать вас в кафе...
# 29  {'article': 'Аромат свежей выпечки, хруст возд...
# 30  {'article': 'Доставим праздничные блюда домой ...
# 31  {'article': 'Бар «ПабиК» снова открыт!<br /><b...
# 32  {'article': 'Незабываемый романтический вечер ...
# 33  {'article': 'Для вас на свет мы появились!<br ...
# 34  {'article': 'Стейк-хаус «Антрекот» — это завед...
# 35  {'article': "«К ПАПЕ НА'PIZZA», гастробар<br /...
# 36  {'article': 'Гриль-бар «ГАЛЕРЕЯ» — это классич...
# 37  {'article': 'Рестобар «ЗдесьВамНеТам» — популя...
# 38  {'article': 'Доставка еды в офис и на дом.<br ...
# 39  {'article': 'Магазины-бары Garage — это высоки...
# 40  {'article': 'Легендарная курочка из Южной Коре...
# 41  {'article': '«Мыльная опера», Томск.<br />Кара...
# 42  {'article': 'Добро пожаловать в Pho Tigers! Ка...
# 43  {'article': 'Приглашаем посетить наше кафе и о...
# 44  {'article': 'Латиноамериканский гастробар в це...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                      attribute_groups                 id  \
# 0   [{'attributes': [{'id': '70000201006747423', '...  70000001056052192
# 1   [{'attributes': [{'id': '70000201006747423', '...  70000001039197290
# 2   [{'attributes': [{'id': '70000201006747423', '...  70000001007548790
# 3   [{'attributes': [{'id': '70000201006747423', '...  70000001033092714
# 4   [{'attributes': [{'id': '70000201006747423', '...  70000001069065093
# 5   [{'attributes': [{'id': '70000201006747423', '...  70000001065471097
# 6   [{'attributes': [{'id': '70000201006747423', '...    422741746350056
# 7   [{'attributes': [{'id': '70000201006747423', '...  70000001034727703
# 8   [{'attributes': [{'id': '70000201006752761', '...  70000001024362908
# 9   [{'attributes': [{'id': '70000201006747423', '...  70000001019311632
# 10  [{'attributes': [{'id': '70000201006747423', '...  70000001032182633
# 11  [{'attributes': [{'id': '70000201006747423', '...  70000001044756053
# 12  [{'attributes': [{'id': '70000201006747423', '...  70000001006736825
# 13  [{'attributes': [{'id': '70000201006747423', '...  70000001043339969
# 14  [{'attributes': [{'id': '70000201006747423', '...  70000001026873949
# 15  [{'attributes': [{'id': '70000201006747423', '...    422740746299978
# 16  [{'attributes': [{'id': '70000201006750805', '...  70000001075243532
# 17  [{'attributes': [{'id': '70000201006747423', '...    422740746242398
# 18  [{'attributes': [{'id': '70000201006747423', '...    422740746052944
# 19  [{'attributes': [{'id': '70000201006747423', '...    422740746095314
# 20  [{'attributes': [{'id': '70000201006747423', '...  70000001029069533
# 21  [{'attributes': [{'id': '70000201006747423', '...  70000001065542142
# 22  [{'attributes': [{'id': '70000201006748004', '...  70000001066379205
# 23  [{'attributes': [{'id': '70000201006747423', '...  70000001066101507
# 24  [{'attributes': [{'id': '70000201006747423', '...  70000001029574004
# 25  [{'attributes': [{'id': '70000201006747423', '...  70000001029908413
# 26  [{'attributes': [{'id': '70000201006747423', '...  70000001038511964
# 27  [{'attributes': [{'id': '70000201006756031', '...  70000001041145942
# 28  [{'attributes': [{'id': '70000201006747423', '...  70000001007410397
# 29  [{'attributes': [{'id': '70000201006748004', '...  70000001045193961
# 30  [{'attributes': [{'id': '70000201006747423', '...  70000001032775451
# 31  [{'attributes': [{'id': '70000201006747423', '...    422740746183350
# 32  [{'attributes': [{'id': '70000201006747423', '...    422740746080455
# 33  [{'attributes': [{'id': '70000201006747423', '...  70000001045371342
# 34  [{'attributes': [{'id': '70000201006747423', '...  70000001024853369
# 35  [{'attributes': [{'id': '70000201006747423', '...  70000001048132291
# 36  [{'attributes': [{'id': '70000201006752761', '...  70000001006338388
# 37  [{'attributes': [{'id': '70000201006747423', '...  70000001028323706
# 38  [{'attributes': [{'id': '70000201006754263', '...  70000001053657643
# 39  [{'attributes': [{'id': '70000201006751153', '...  70000001067269176
# 40  [{'attributes': [{'id': '70000201006747423', '...  70000001059971139
# 41  [{'attributes': [{'id': '70000201006747423', '...  70000001036187192
# 42  [{'attributes': [{'id': '70000201006747423', '...  70000001034903505
# 43  [{'attributes': [{'id': '70000201006747423', '...  70000001035530724
# 44  [{'attributes': [{'id': '70000201006748029', '...  70000001052467336
# 45  [{'attributes': [{'id': '70000201006747423', '...    422741746676019
# 46  [{'attributes': [{'id': '70000201006747423', '...    422740746481943
# 47  [{'attributes': [{'id': '70000201006747423', '...  70000001044960809
# 48  [{'attributes': [{'id': '70000201006747423', '...  70000001027792986
# 49  [{'attributes': [{'id': '70000201006747423', '...    422740746329503
#
#                                              name  \
# 0                Шаурмания, кафе быстрого питания
# 1                          Барин, коктейльный бар
# 2                             Шашлычный дом, кафе
# 3              TomYumBar, кафе паназиатской кухни
# 4                                     Ватан, кафе
# 5             ПхиПхи, ресторан паназиатской кухни
# 6                                           Dolce
# 7                    Пряности и радости, ресторан
# 8                                КУХНЯ, повар-бар
# 9                       The burger lab, гастробар
# 10       Мама, я дома!, ресторан грузинской кухни
# 11                                  Highlight Bar
# 12             Река 827, ресторан авторской кухни
# 13                                         Subway
# 14              Территория Кофе, экспресс-кофейня
# 15             Колобок.Ру, сеть кафе уютной кухни
# 16                                          Елань
# 17              PastaMama, кафе итальянской кухни
# 18                                Инжир, ресторан
# 19            Бамбук, ресторан паназиатской кухни
# 20                             ХинКали-GaлИ, кафе
# 21                      Додо Пицца, сеть пиццерий
# 22                                Glogg, ресторан
# 23                                           Nova
# 24                                    Гости, кафе
# 25  Бургер Кинг, сеть ресторанов быстрого питания
# 26                             Santa Monica, кафе
# 27               Ё, служба доставки суши и роллов
# 28                                   Байкал, кафе
# 29       А мы тут плюшками балуемся, кафе-пекарня
# 30                                     Союз, кафе
# 31                                     ПабиК, бар
# 32                              Шустофф, ресторан
# 33                         Пицца cиница, пиццерия
# 34                           Антрекот, стейк-хаус
# 35                     К ПАПЕ НА`PIZZA, гастробар
# 36                             Галерея, гриль-бар
# 37                        ЗдесьВамНеТам, ресторан
# 38                            Доставка Саша варит
# 39                                         Garage
# 40           Kannam Сhicken, кафе корейской кухни
# 41                    Мыльная опера, караоке-клуб
# 42               Pho Tigers, кафе азиатской кухни
# 43                                  Бульвар, кафе
# 44     El Mucho Bar, латиноамериканский гастробар
# 45                           Шашлыкоff, гриль-бар
# 46                               Буланже, кофейня
# 47                                 Безумно.Шаурма
# 48                       Мэйк лав пицца, пиццерия
# 49                       Пицце-Рио, кафе-пиццерия
#
#                                             reviews_x    type  \
# 0   {'general_rating': 4.3, 'general_review_count'...  branch
# 1   {'general_rating': 4.6, 'general_review_count'...  branch
# 2   {'general_rating': 4.4, 'general_review_count'...  branch
# 3   {'general_rating': 3.6, 'general_review_count'...  branch
# 4   {'general_rating': 4.8, 'general_review_count'...  branch
# 5   {'general_rating': 3.9, 'general_review_count'...  branch
# 6   {'general_rating': 4.5, 'general_review_count'...  branch
# 7   {'general_rating': 4, 'general_review_count': ...  branch
# 8   {'general_rating': 4.2, 'general_review_count'...  branch
# 9   {'general_rating': 4.2, 'general_review_count'...  branch
# 10  {'general_rating': 4.1, 'general_review_count'...  branch
# 11  {'general_rating': 4.6, 'general_review_count'...  branch
# 12  {'general_rating': 4.4, 'general_review_count'...  branch
# 13  {'general_rating': 3.1, 'general_review_count'...  branch
# 14  {'general_rating': 4.4, 'general_review_count'...  branch
# 15  {'general_rating': 3.9, 'general_review_count'...  branch
# 16  {'general_rating': 5, 'general_review_count': ...  branch
# 17  {'general_rating': 3.6, 'general_review_count'...  branch
# 18  {'general_rating': 4.2, 'general_review_count'...  branch
# 19  {'general_rating': 4.1, 'general_review_count'...  branch
# 20  {'general_rating': 3.5, 'general_review_count'...  branch
# 21  {'general_rating': 4.1, 'general_review_count'...  branch
# 22  {'general_rating': 4.8, 'general_review_count'...  branch
# 23  {'general_rating': 3.5, 'general_review_count'...  branch
# 24  {'general_rating': 3.9, 'general_review_count'...  branch
# 25  {'general_rating': 2.5, 'general_review_count'...  branch
# 26  {'general_rating': 4.3, 'general_review_count'...  branch
# 27  {'general_rating': 4.1, 'general_review_count'...  branch
# 28  {'general_rating': 4.2, 'general_review_count'...  branch
# 29  {'general_rating': 4, 'general_review_count': ...  branch
# 30  {'general_rating': 4.3, 'general_review_count'...  branch
# 31  {'general_rating': 4.1, 'general_review_count'...  branch
# 32  {'general_rating': 4.2, 'general_review_count'...  branch
# 33  {'general_rating': 3.7, 'general_review_count'...  branch
# 34  {'general_rating': 4.4, 'general_review_count'...  branch
# 35  {'general_rating': 4.6, 'general_review_count'...  branch
# 36  {'general_rating': 4.3, 'general_review_count'...  branch
# 37  {'general_rating': 4.3, 'general_review_count'...  branch
# 38  {'general_rating': 4.1, 'general_review_count'...  branch
# 39  {'general_rating': 3.3, 'general_review_count'...  branch
# 40  {'general_rating': 4.6, 'general_review_count'...  branch
# 41  {'general_rating': 3.5, 'general_review_count'...  branch
# 42  {'general_rating': 4.1, 'general_review_count'...  branch
# 43  {'general_rating': 4.5, 'general_review_count'...  branch
# 44  {'general_rating': 4.2, 'general_review_count'...  branch
# 45  {'general_rating': 4.1, 'general_review_count'...  branch
# 46  {'general_rating': 4, 'general_review_count': ...  branch
# 47  {'general_rating': 4.7, 'general_review_count'...  branch
# 48  {'general_rating': 4.6, 'general_review_count'...  branch
# 49  {'general_rating': 3.4, 'general_review_count'...  branch
#
#          address_comment                        full_name purpose_name  \
# 0                    NaN                              NaN          NaN
# 1                    NaN                              NaN          NaN
# 2                    NaN                              NaN          NaN
# 3                    NaN                              NaN          NaN
# 4                 2 этаж                              NaN          NaN
# 5         цокольный этаж                              NaN          NaN
# 6                    NaN                              NaN          NaN
# 7                    NaN        Томск, площадь Ленина, 10     Ресторан
# 8                    NaN                              NaN          NaN
# 9                 1 этаж                              NaN          NaN
# 10                3 этаж                              NaN          NaN
# 11                3 этаж                              NaN          NaN
# 12                1 этаж                              NaN          NaN
# 13                   NaN                              NaN          NaN
# 14                   NaN                 Томск, Усова, 9Б      Магазин
# 15                   NaN                              NaN          NaN
# 16                   NaN                              NaN          NaN
# 17  1 этаж; правое крыло                              NaN          NaN
# 18                2 этаж                              NaN          NaN
# 19                   NaN                              NaN          NaN
# 20                   NaN                              NaN          NaN
# 21                   NaN                              NaN          NaN
# 22                   NaN                              NaN          NaN
# 23                   NaN                              NaN          NaN
# 24                   NaN                              NaN          NaN
# 25                1 этаж                              NaN          NaN
# 26                   NaN                              NaN          NaN
# 27                   NaN                              NaN          NaN
# 28        цокольный этаж                              NaN          NaN
# 29                   NaN                              NaN          NaN
# 30                2 этаж                              NaN          NaN
# 31                   NaN                              NaN          NaN
# 32                   NaN  Томск, Иркутский тракт, 61 ст12    Кафе, бар
# 33                   NaN                              NaN          NaN
# 34                2 этаж                              NaN          NaN
# 35        цокольный этаж                              NaN          NaN
# 36        цокольный этаж                              NaN          NaN
# 37        цокольный этаж                              NaN          NaN
# 38                   NaN                              NaN          NaN
# 39                   NaN                              NaN          NaN
# 40                2 этаж                              NaN          NaN
# 41                   NaN                              NaN          NaN
# 42                   NaN                              NaN          NaN
# 43                   NaN                              NaN          NaN
# 44                2 этаж                              NaN          NaN
# 45                1 этаж                              NaN          NaN
# 46                2 этаж                              NaN          NaN
# 47                   NaN                              NaN          NaN
# 48                1 этаж                              NaN          NaN
# 49                1 этаж                              NaN          NaN
#
#     avg_price  general_rating  \
# 0         270             4.3
# 1        1200             4.6
# 2         230             4.4
# 3        1000             3.6
# 4         500             4.8
# 5        1000             3.9
# 6         350             4.5
# 7        2500             4.0
# 8         360             4.2
# 9         600             4.2
# 10       1700             4.1
# 11       1200             4.6
# 12       1700             4.4
# 13        300             3.1
# 14        200             4.4
# 15        180             3.9
# 16          0             5.0
# 17       1200             3.6
# 18       1500             4.2
# 19       1500             4.1
# 20        550             3.5
# 21        514             4.1
# 22          0             4.8
# 23        825             3.5
# 24        800             3.9
# 25        450             2.5
# 26       1000             4.3
# 27          0             4.1
# 28        300             4.2
# 29          0             4.0
# 30       1100             4.3
# 31       1200             4.1
# 32       1800             4.2
# 33        495             3.7
# 34       1000             4.4
# 35       1000             4.6
# 36        400             4.3
# 37        790             4.3
# 38          0             4.1
# 39          0             3.3
# 40        600             4.6
# 41       1500             3.5
# 42        600             4.1
# 43       1500             4.5
# 44          0             4.2
# 45        500             4.1
# 46        500             4.0
# 47        250             4.7
# 48        350             4.6
# 49        375             3.4
#
#                                              cuisines  \
# 0                                                 NaN
# 1                                                 NaN
# 2                   Кавказская кухня, Армянская кухня
# 3                                  Паназиатская кухня
# 4                    Восточная кухня, Еврейская кухня
# 5                                  Паназиатская кухня
# 6                                                 NaN
# 7                 Грузинская кухня, Европейская кухня
# 8   Азиатская кухня, Русская кухня, Европейская кухня
# 9   Европейская кухня, Вегетарианская кухня, Амери...
# 10                                   Грузинская кухня
# 11                   Русская кухня, Европейская кухня
# 12                                  Европейская кухня
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17               Итальянская кухня, Европейская кухня
# 18                                    Восточная кухня
# 19                 Японская кухня, Паназиатская кухня
# 20                                   Грузинская кухня
# 21                                                NaN
# 22                                                NaN
# 23               Итальянская кухня, Европейская кухня
# 24                   Русская кухня, Европейская кухня
# 25                                                NaN
# 26  Мексиканская кухня, Европейская кухня, Америка...
# 27                                                NaN
# 28    Бурятская кухня, Японская кухня, Якутская кухня
# 29                                                NaN
# 30                   Русская кухня, Европейская кухня
# 31                                  Европейская кухня
# 32                   Русская кухня, Европейская кухня
# 33                                  Итальянская кухня
# 34              Европейская кухня, Американская кухня
# 35                                                NaN
# 36                                                NaN
# 37  Итальянская кухня, Японская кухня, Европейская...
# 38                                                NaN
# 39                                                NaN
# 40                     Корейская кухня, Тайская кухня
# 41  Итальянская кухня, Русская кухня, Европейская ...
# 42                  Паназиатская кухня, Тайская кухня
# 43                   Русская кухня, Европейская кухня
# 44                Гавайская кухня, Мексиканская кухня
# 45                                      Русская кухня
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                             reviews_y
# 0   ['Очень вкусная шаурма, прям реально! Впечатли...
# 1   ['Замечательно и весело!спасибо 🥰', 'Атмосферн...
# 2   ['Сочные стейки, приготовленные в тандыре - бе...
# 3   ['Обслуживание ниже среднего. Официантов не до...
# 4   ['Хочу рассказать о этом заведение. Был первый...
# 5   ['Дизайн этого ресторана меня покорил сразу, я...
# 6   ['В качестве гостя в Томске я уже пятый раз, н...
# 7   ['На летней веранде обслуживание НОЛЬ!!! После...
# 8   ['Были на бизнес ланче.\nЕда вкусная!\nОбслужи...
# 9   ['Место с отличными бургерами, вежливыми и чут...
# 10  ['Я не первый раз у вас и каждый раз все больш...
# 11  ['Отличное место! Была у вас в первые и обязат...
# 12  ['Ресторан супер, вежливый и отзывчивый персон...
# 13  ['Тут знают, что котлеты надо разогревать отде...
# 14  ['Очень вкусные завтраки и кофе!\nОфицианты са...
# 15  ['Что хочется сказать об этом заведении.  Начн...
# 16  ['Если у вас есть желание попробовать новые вк...
# 17  ['Очень грустно! Так хотелось ризотто но в ито...
# 18  ['Отмечали юбилей серебряной свадьбы с мужем. ...
# 19  ['Роллы как всегда вкусные, лучшие в городе. Н...
# 20  ['Добрый день. Сильно понравилось кафе "ХинКал...
# 21  ['Все отлично 🙌🏻', 'Красивые милые девочки, ка...
# 22  ['Очень приятное место! Чисто, доброжелательно...
# 23  ['Добрый день,\n\nЯ хотел бы выразить свою бла...
# 24  ['Хорошее место', 'Кухня приличная, даже вкусн...
# 25  ['Все понравилось, вкусно', 'Долго отдавали за...
# 26  ['Вкусно, все что взяли 10 из 10.', 'Чудесное ...
# 27  ['Быстрая доставка всё супер', 'Фаворит среди ...
# 28  ['Прекрасное место!\nКормят ну очень вкусно!\n...
# 29  ['Завтраки интересные и вкусные, народу куча, ...
# 30  ['Было 40 минут времени, решила поужинать. \nВ...
# 31  ['Замечательное место. Понравилось меню, обслу...
# 32  ['27.05.2023 отмечали свадьбу. С выбором ресто...
# 33  ['Обещали приготовить пиццу через 15 мин, в ре...
# 34  ['✨Была бы оценка 10, я бы поставила 10/10. ✨З...
# 35  ['Доброго дня, была в вашем заведения, мне оче...
# 36  ['Очень хорошее заведение: вкусная еда, отличн...
# 37  ['Посоветовал знакомый сходить в этот бар. Поп...
# 38  ['Всегда раньше покупала вашу продукцию в буфе...
# 39  ['Получили вот такой флаер, идем по пути, дума...
# 40  ['Очень вкусные крылья - не все соусы понравил...
# 41  ['Был первый раз очень понравилось. Персонал с...
# 42  ['Мало места в кафе.Небыло в меню некоторых бл...
# 43  ['быстрое и качественное обслуживание.', 'Ходи...
# 44  ['Очень приятное место с хорошей кухней. Быстр...
# 45  ['Зачем вводить систему с песочными часами есл...
# 46  ['Ну Во-первых ОЧ вкусно! Кофе- бесподобный! П...
# 47  ['Топ шава, берите пикантная+шрирача+холопенье...
# 48  ['Пишу, не откладывая в долгий ящик.\nПолчаса ...
# 49  ['Очень миленько у них. А вообще часто берем и...
